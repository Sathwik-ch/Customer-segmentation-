# %% [markdown]
# <a href="https://colab.research.google.com/github/Sathwik-ch/Customer-segmentation-/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("Mall_Customers.csv")

# %%
from sklearn.cluster import KMeans

# %%
print(data.head())
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2  Female   21                  15                      81
# 2           3    Male   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5    Male   31                  17                      40

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None

# %%
print(data.describe())
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   28.800000           17.000000               49.400000
# std     57.879185   12.805464            1.417762               33.376789
# min      1.000000   19.000000           15.000000                3.000000
# 25%     50.750000   21.000000           16.000000                6.000000
# 50%    100.500000   23.000000           17.000000               56.000000
# 75%    150.250000   31.000000           18.000000               77.000000
# max    200.000000   64.000000           19.000000               94.000000

# %%
plt.figure(figsize=(12,4))

# %%
plt.subplot(1,2,1)
# Out:
# <Axes: >

# %%
sns.histplot(data['Annual Income (k$)'], kde=True)
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Count'>

# %%
plt.title('Annual Income Distribution')
# Out:
# Text(0.5, 1.0, 'Annual Income Distribution')

# %%
plt.subplot(1,2,2)
# Out:
# <Axes: >

# %%
sns.histplot(data['Spending Score (1-100)'], kde=True)
# Out:
# <Axes: xlabel='Spending Score (1-100)', ylabel='Count'>

# %%
plt.title('Spending Score Distribution')
# Out:
# Text(0.5, 1.0, 'Spending Score Distribution')

# %%
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
sns.histplot(data['Annual Income (k$)'], kde=True)
plt.title('Annual Income Distribution')

plt.subplot(1,2,2)
sns.histplot(data['Spending Score (1-100)'], kde=True)
plt.title('Spending Score Distribution')
plt.show()

# %%
X = data[['Annual Income (k$)', 'Spending Score (1-100)']]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
clusters = kmeans.fit_predict(X_scaled)
data['Cluster'] = clusters

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=X_scaled[:,0], y=X_scaled[:,1], hue=clusters, palette='rainbow', s=100)
plt.title('Customer Segments')
plt.xlabel('Annual Income (scaled)')
plt.ylabel('Spending Score (scaled)')
plt.show()

# %%
cluster_summary = data.groupby('Cluster').mean(numeric_only=True)
print(cluster_summary)
# Out:
#          CustomerID   Age  Annual Income (k$)  Spending Score (1-100)
# Cluster
# 0             100.0  31.0                17.0               40.000000
# 1             103.0  25.0                18.0               80.666667
# 2              98.0  22.0                15.5               79.000000
# 3              97.0  19.5                15.5               22.500000
# 4             103.0  49.5                18.5                4.500000
